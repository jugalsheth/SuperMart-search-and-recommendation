# %%
import re
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sparse_dot_topn import awesome_cossim_topn

# %%
df = pd.read_csv('superstore_final.csv',encoding= 'unicode_escape')

# %%
df.head()
# Out:
#    Row ID         Order ID Order Date Ship Date       Ship Mode  Customer ID  \
# 0   42433     AG-2011-2040   1/1/2014  6/1/2014  Standard Class            8
# 1   22253    IN-2011-47883   1/1/2014  8/1/2014  Standard Class            9
# 2   48883     HU-2011-1220   1/1/2014  5/1/2014    Second Class           12
# 3   11731  IT-2011-3647632   1/1/2014  5/1/2014    Second Class           20
# 4   22255    IN-2011-47883   1/1/2014  8/1/2014  Standard Class           24
#
#        Customer Name      Segment         City            State  ...  \
# 0    Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1        Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2      Annie Thurman     Consumer     Budapest         Budapest  ...
# 3       Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4  Patrick O'Donnell     Consumer        Dhaka            Dhaka  ...
#
#           Category  Sub-Category          ProductName    Sales  Quantity  \
# 0  Office Supplies       Storage  Tenex Lockers, Blue  408.300         2
# 1  Office Supplies       Storage  Tenex Lockers, Blue  120.366         3
# 2  Office Supplies       Storage  Tenex Lockers, Blue   66.120         4
# 3  Office Supplies       Storage  Tenex Lockers, Blue   44.865         3
# 4  Office Supplies       Storage  Tenex Lockers, Blue  113.670         5
#
#   Discount   Profit Shipping Cost  Order Priority  Rating
# 0      0.0  106.140         35.46          Medium     4.0
# 1      0.1   36.036          9.72          Medium     4.5
# 2      0.0   29.640          8.17            High     4.0
# 3      0.5  -26.055          4.82            High     4.0
# 4      0.1   37.770          4.70          Medium     4.0
#
# [5 rows x 25 columns]

# %%
product_list=df['ProductID'].unique()
products = pd.DataFrame()
products['ProductID'] = product_list
products
# Out:
#      ProductID
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ..         ...
# 411        436
# 412        437
# 413        438
# 414        439
# 415        440
#
# [416 rows x 1 columns]

# %%
vals=df['ProductName'].unique().astype('U')
vals
# Out:
# array(['Tenex Lockers, Blue', 'Acme Trimmer, High Speed',
#        'Tenex Box, Single Width', 'Enermax Note Cards, Premium',
#        'Eldon Light Bulb, Duo Pack',
#        'Eaton Computer Printout Paper, 8.5 x 11',
#        'Brother Personal Copier, Laser',
#        'Sauder Facets Collection Library, Sky Alder Finish',
#        'Fellowes Lockers, Wire Frame', 'Tenex Trays, Single Width',
#        'KitchenAid Coffee Grinder, Red',
#        'Hamilton Beach Refrigerator, Silver',
#        'Advantus Photo Frame, Erganomic',
#        'Binney & Smith Pencil Sharpener, Easy-Erase',
#        'Kleencut Ruler, High Speed', 'Memorex Memory Card, USB',
#        'Sanford Pencil Sharpener, Water Color',
#        'Wilson Jones Hole Reinforcements, Economy',
#        'Smead File Folder Labels, Adjustable',
#        'GlobeWeis Peel and Seal, Set of 50',
#        'Acco Hole Reinforcements, Recycled',
#        'Avery Hole Reinforcements, Durable',
#        'Wilson Jones Hole Reinforcements, Clear',
#        'Fellowes File Cart, Industrial',
#        'Safco Classic Bookcase, Traditional',
#        'Logitech Router, Erganomic', 'Hamilton Beach Toaster, Black',
#        'Novimex Swivel Fabric Task Chair',
#        'Harbour Creations Bag Chairs, Red',
#        'Office Star Rocking Chair, Red', 'Fellowes Lockers, Single Width',
#        'Panasonic Receipt Printer, White',
#        "Global Deluxe High-Back Manager's Chair",
#        'Sharp Fax Machine, High-Speed',
#        'Bevis Round Conference Room Tables and Bases',
#        'BIC Sketch Pad, Blue', 'Harbour Creations Steel Folding Chair',
#        'Hon Steel Folding Chair, Red', 'Fellowes Shelving, Single Width',
#        'Apple Speaker Phone, with Caller ID', 'BIC Markers, Easy-Erase',
#        'Konica Printer, White', 'Tenex Clock, Black',
#        'Hon Swivel Stool, Red', 'Kraft Peel and Seal, Security-Tint',
#        'Belkin Keyboard, USB', 'Cisco Signal Booster, Full Size',
#        'Safco Floating Shelf Set, Traditional',
#        'Smead Shelving, Single Width',
#        'Recycled Steel Personal File for Hanging File Folders',
#        'Stanley Canvas, Blue', 'Fellowes Folders, Blue',
#        'Fellowes Bankers Box Recycled Super Stor/Drawer',
#        'DAX Black Cherry Wood-Tone Poster Frame',
#        'StarTech Receipt Printer, Wireless',
#        'Acco 3-Hole Punch, Recycled', 'Epson Calculator, Durable',
#        'Acme Scissors, Easy Grip', 'Xerox Parchment Paper, Premium',
#        'Eldon Box, Single Width', 'Sanford Pens, Fluorescent',
#        'Binney & Smith Pens, Easy-Erase', 'Fellowes Shelving, Wire Frame',
#        'OIC Push Pins, Assorted Sizes',
#        'Hon Shipping Labels, 5000 Label Set',
#        'Novimex Bag Chairs, Adjustable',
#        'Plymouth Boxed Rubber Bands by Plymouth',
#        'Black Print Carbonless 8 1/2" x 8 1/4" Rapid Memo Book',
#        'Hon Round Labels, Laser Printer Compatible',
#        'Ibico Index Tab, Clear', 'Tenex Box, Wire Frame',
#        'Hoover Toaster, Silver',
#        'Sannysis Cute Owl Design Soft Skin Case Cover for Samsung Galaxy S4',
#        'Apple Signal Booster, Full Size',
#        'Wilson Jones Binding Machine, Recycled',
#        'Ikea 3-Shelf Cabinet, Metal', 'Stanley Canvas, Water Color',
#        'Motorola Audio Dock, with Caller ID',
#        'Cardinal Binding Machine, Clear', 'Cuisinart Toaster, Red',
#        'SanDisk Flash Drive, Programmable',
#        'Memorex Memory Card, Erganomic', 'Memorex Keyboard, Bluetooth',
#        'Novimex Chairmat, Red', 'Rogers Trays, Wire Frame',
#        'Stanley Markers, Easy-Erase', 'Rubbermaid Stacking Tray, Durable',
#        'Smead Folders, Single Width', 'Avery 490',
#        'Rogers Box, Wire Frame', 'Cardinal Hole Reinforcements, Economy',
#        'Rogers Profile Extra Capacity Storage Tub',
#        'Cardinal Hole Reinforcements, Durable',
#        'Cardinal Binder Covers, Clear',
#        'Pressboard Data Binder, Crimson, 12" X 8 1/2"',
#        'Zipper Ring Binder Pockets', 'Avery Round Labels, Adjustable',
#        'Jiffy Clasp Envelope, Recycled',
#        'Harbour Creations Swivel Stool, Black',
#        'Ikea Classic Bookcase, Traditional',
#        "Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room",
#        'Adtran 1202752G1', 'Enermax Numeric Keypad, Bluetooth',
#        'Dania Library with Doors, Metal',
#        'SanDisk Memory Card, Bluetooth', 'Enermax Keyboard, Bluetooth',
#        'Samsung Audio Dock, VoIP', 'Sanford Pencil Sharpener, Easy-Erase',
#        'Apple Speaker Phone, Full Size', 'Fellowes File Cart, Wire Frame',
#        'Cameo Peel and Seal, Security-Tint', 'Enermax Mouse, Erganomic',
#        'Boston Heavy-Duty Trimline Electric Pencil Sharpeners',
#        'Cardinal Binding Machine, Durable',
#        'Wilson Jones Heavy-Duty Casebound Ring Binders with Metal Hinges',
#        'Eldon Shelving, Blue', 'Cardinal 3-Hole Punch, Economy',
#        'Safco Steel Mobile File Cart',
#        'Enermax Numeric Keypad, Erganomic', 'Smead Trays, Blue',
#        'Acco 6 Outlet Guardian Premium Surge Suppressor',
#        'Harbour Creations Steel Folding Chair, Red',
#        'Adams Telephone Message Book w/Frequently-Called Numbers Space, 400 Messages per Book',
#        'Kraft Clasp Envelope, with clear poly window',
#        'Wilson Jones Index Tab, Durable',
#        'Kraft Manila Envelope, Recycled', 'Sanford Canvas, Fluorescent',
#        'Wilson Jones 3-Hole Punch, Economy',
#        '3M Hangers With Command Adhesive', 'Xerox 205',
#        'Kraft Interoffice Envelope, with clear poly window',
#        'Avery Binder Covers, Economy',
#        'Stockwell Thumb Tacks, Assorted Sizes',
#        'GBC Clear Cover, 8-1/2 x 11, unpunched, 25 covers per pack',
#        'Advantus Staples, Bulk Pack',
#        'Ibico Hole Reinforcements, Economy',
#        'Lesro Round Table, Rectangular',
#        'Wilson SignalBoost 841262 DB PRO Amplifier Kit',
#        'Chromcraft Computer Table, Fully Assembled',
#        'BIC Highlighters, Blue', 'Bush Floating Shelf Set, Mobile',
#        'Xerox Cards & Envelopes, Multicolor',
#        'Sanford Highlighters, Fluorescent', 'Eldon Door Stop, Erganomic',
#        'Cardinal Holdit Business Card Pockets', 'Acco Index Tab, Clear',
#        'Avery Durable Binders', 'Brother Fax and Copier, Color',
#        'Konica Card Printer, Red',
#        'Office Star Executive Leather Armchair, Adjustable',
#        'SAFCO Executive Leather Armchair, Red',
#        'Harbour Creations Steel Folding Chair, Set of Two',
#        'Belkin Flash Drive, Programmable',
#        'Rogers Shelving, Single Width', 'Stanley Canvas, Easy-Erase',
#        'Cuisinart Microwave, Silver', 'Tenex Shelving, Industrial',
#        'Hoover Coffee Grinder, White',
#        'Accos Paper Clips, Assorted Sizes',
#        'Ames Peel and Seal, Recycled',
#        'Safco Library with Doors, Traditional',
#        'Stiletto Box Cutter, Serrated',
#        'Cardinal Binding Machine, Recycled',
#        'Eldon File Cart, Industrial', 'Tenex Door Stop, Erganomic',
#        'Memorex Numeric Keypad, Erganomic', 'Xerox 1916',
#        'Honeywell Quietcare HEPA Air Cleaner',
#        'Acme Scissors, High Speed', '9-3/4 Diameter Round Wall Clock',
#        'SanDisk Memory Card, Erganomic',
#        'Wilson Jones data.warehouse D-Ring Binders with DublLock',
#        'Cardinal Binder Covers, Economy', 'Ibico 3-Hole Punch, Clear',
#        'Xerox Memo Slips, Multicolor', 'Avery Binder, Recycled',
#        'Advantus Paper Clips, Metal',
#        'Avery Legal Exhibit Labels, 5000 Label Set',
#        'Enermax Mouse, Bluetooth',
#        'Self-Adhesive Address Labels for Typewriters by Universal',
#        'Harbour Creations Round Labels, Alphabetical',
#        'Stanley Pencil Sharpener, Easy-Erase',
#        'Acco Clips to Go Binder Clips, 24 Clips in Two Sizes',
#        'Fellowes Box, Single Width', 'Epson Inkjet, Wireless',
#        'Eldon File Cart, Single Width', 'Cisco Audio Dock, Full Size',
#        'Xerox Computer Printout Paper, 8.5 x 11',
#        'Harbour Creations Executive Leather Armchair, Black',
#        'WD My Passport Ultra 2TB Portable External Hard Drive',
#        'Sauder Classic Bookcase, Metal',
#        'SAFCO Executive Leather Armchair, Adjustable',
#        'Deflect-O Door Stop, Black', 'Breville Coffee Grinder, Silver',
#        'Tenex Folders, Single Width', 'Xerox 216',
#        'Avery Binding Machine, Durable', 'Acme Scissors, Serrated',
#        'Fiskars Trimmer, Serrated', 'Ibico Index Tab, Durable',
#        'BIC Pencil Sharpener, Fluorescent', 'Rogers Box, Single Width',
#        'Wilson Jones Hanging Recycled Pressboard Data Binders',
#        'BOSTON Model 1800 Electric Pencil Sharpeners, Putty/Woodgrain',
#        'Boston Pencil Sharpener, Fluorescent',
#        'Avery Round Labels, Laser Printer Compatible',
#        'Hon Round Labels, Adjustable', 'Prestige Round Ring Binders',
#        'SanDisk Router, Erganomic', 'HP Fax and Copier, Color',
#        'Ibico Binding Machine, Recycled', 'Eldon Folders, Industrial',
#        'Cuisinart Blender, Black', 'Ames Peel and Seal, Set of 50',
#        'OIC Rubber Bands, 12 Pack', 'Ibico Hole Reinforcements, Clear',
#        'Sterling Rubber Bands by Alliance',
#        'ClearOne CHATAttach 160 -\xa0speaker phone',
#        'Memorex Router, Programmable', 'Brother Fax Machine, Laser',
#        'Enermax Router, Bluetooth', 'Rogers File Cart, Single Width',
#        'Canon Copy Machine, Color',
#        'Cisco IP\xa0Phone\xa07961G VoIP\xa0phone\xa0- Dark gray',
#        'Carina Mini System Audio Rack, Model AR050B',
#        'Bush Library with Doors, Traditional',
#        'Avery Binding Machine, Recycled',
#        'Dania Floating Shelf Set, Traditional', 'Elite Shears, Easy Grip',
#        'Fellowes Lockers, Industrial', 'StarTech Calculator, Red',
#        'Canon Ink, Laser', 'KitchenAid Coffee Grinder, Silver',
#        'Kensington 7 Outlet MasterPiece Power Center',
#        'Jiffy Business Envelopes, Recycled', 'Okidata Printer, White',
#        'Novimex Chairmat, Black', 'Fellowes File Cart, Blue',
#        'Tenex Lockers, Single Width', 'Acco Binding Machine, Economy',
#        'Smead File Cart, Single Width', 'Acme Trimmer, Steel',
#        'Stiletto Shears, High Speed',
#        'Boston Pencil Sharpener, Water Color', 'Smead Shelving, Blue',
#        'Rogers Folders, Industrial', 'Eaton Cards & Envelopes, 8.5 x 11',
#        'Fellowes Superior 10 Outlet Split Surge Protector',
#        'Enermax Mouse, Programmable', 'Samsung Speaker Phone, Cordless',
#        'Multi-Use Personal File Cart and Caster Set, Three Stacking Bins',
#        'Novimex Chairmat, Adjustable',
#        'Howard Miller 13" Diameter Pewter Finish Round Wall Clock',
#        'Jiffy Peel and Seal, with clear poly window',
#        'Eaton Note Cards, Premium', 'Epson Calculator, Wireless',
#        'Panasonic Calculator, Red', 'Cardinal 3-Hole Punch, Recycled',
#        'Wilson Jones 3-Hole Punch, Clear', 'Stanley Markers, Fluorescent',
#        'Rogers Trays, Blue', 'Avery 513',
#        'Plantronics Voyager Pro HD - Bluetooth Headset',
#        'Enermax Keyboard, Erganomic', 'Elite Ruler, Serrated',
#        'Avery Hole Reinforcements, Recycled', 'Xerox 1934',
#        'Avery Shipping Labels, Laser Printer Compatible', 'Avery 475',
#        'Harbour Creations File Folder Labels, Adjustable',
#        'Model L Table or Wall-Mount Pencil Sharpener',
#        'Binney & Smith Highlighters, Blue',
#        'Avery 3-Hole Punch, Recycled', 'Master Big Foot Doorstop, Beige',
#        'Southworth Parchment Paper & Envelopes',
#        'Sanford Highlighters, Blue', 'GBC Standard Therm-A-Bind Covers',
#        'Stockwell Push Pins, Assorted Sizes', 'Newell 320', 'Staples',
#        'OIC #2 Pencils, Medium Soft', 'Smead Box, Wire Frame',
#        'Acco Economy Flexible Poly Round Ring Binder',
#        'Office Star - Professional Matrix Back Chair with 2-to-1 Synchro Tilt and Mesh Fabric Seat',
#        'Belkin Router, Erganomic', 'Hon Multipurpose Stacking Arm Chairs',
#        'Hon 4070 Series Pagoda Round Back Stacking Chairs',
#        'Bevis Computer Table, Adjustable Height',
#        'Brother Wireless Fax, Laser', 'Acco Binding Machine, Recycled',
#        'Sharp 1540cs Digital Laser Copier', 'Rubbermaid Frame, Black',
#        'Sauder Corner Shelving, Traditional',
#        'Eldon Shelving, Single Width', 'Hewlett Personal Copier, Digital',
#        'Kraft Peel and Seal, Recycled', 'SAFCO Bag Chairs, Set of Two',
#        'Ikea Stackable Bookrack, Mobile', 'Deflect-O Frame, Black',
#        'Hon Shipping Labels, Laser Printer Compatible',
#        'Hunt BOSTON Vista Battery-Operated Pencil Sharpener, Black',
#        'Fellowes Shelving, Industrial', 'SanDisk Mouse, Bluetooth',
#        'Eaton Note Cards, 8.5 x 11', 'Linden 10" Round Wall Clock, Black',
#        'Floodlight Indoor Halogen Bulbs, 1 Bulb per Pack, 60 Watts',
#        'BlueLounge Milo Smartphone Stand, White/Metallic',
#        'Motorola Headset, Full Size', 'Rubbermaid Light Bulb, Black',
#        'Avery Shipping Labels, 5000 Label Set',
#        'Advantus Rubber Bands, Assorted Sizes',
#        'BIC Markers, Water Color', 'Eaton Message Books, Recycled',
#        'Xerox 214', 'Hon Bag Chairs, Black', 'Cardinal Binder, Clear',
#        'OIC Paper Clips, 12 Pack', 'Ultra Door Push Plate',
#        'Avery Shipping Labels, Alphabetical',
#        'Master Caster Door Stop, Brown', 'Ibico Binder Covers, Clear',
#        'Smead Shipping Labels, Adjustable', 'Okidata Inkjet, Wireless',
#        'Safco Stackable Bookrack, Pine',
#        'Motorola Signal Booster, Cordless', 'Hewlett Copy Machine, Color',
#        'Eldon File Cart, Blue', 'Cisco Smart Phone, Full Size',
#        'Bevis Computer Table, Fully Assembled',
#        'Enermax Aurora Lite Keyboard', 'Ikea Library with Doors, Pine',
#        'Cisco Headset, Full Size',
#        'Novimex Executive Leather Armchair, Black',
#        'Epson Receipt Printer, Wireless',
#        'SAFCO Steel Folding Chair, Black', 'HP Fax and Copier, Digital',
#        'Konica Phone, White', 'SanDisk Memo Slips, Multicolor',
#        'Logitech Numeric Keypad, Erganomic',
#        'Boston Highlighters, Water Color', 'BIC Canvas, Water Color',
#        'Acme Box Cutter, High Speed', 'Sanford Highlighters, Water Color',
#        'Xerox Note Cards, Premium',
#        'Avery Color Coded Labels, 5000 Label Set',
#        'Rubbermaid Light Bulb, Duo Pack',
#        'Ikea Corner Shelving, Traditional', 'Ikea 3-Shelf Cabinet, Pine',
#        'Office Star Executive Leather Armchair, Black',
#        'Harbour Creations Steel Folding Chair, Black',
#        'Canon Wireless Fax, Digital', 'Rogers Lockers, Wire Frame',
#        'Hypercom P1300 Pinpad', 'Acco Binder Covers, Durable',
#        'Enermax Message Books, 8.5 x 11',
#        'Array Parchment Paper, Assorted Colors',
#        'Stanley Markers, Water Color', 'Xerox 1971',
#        'KitchenAid Stove, Black', 'Motorola Droid Maxx',
#        'Samsung Smart Phone, Cordless', 'HP Ink, High-Speed',
#        'Okidata Card Printer, White', 'Hewlett Fax and Copier, Laser',
#        'Euro-Pro Shark Turbo Vacuum', 'Luxo Adjustable Task Clamp Lamp',
#        'Canon Personal Copier, Color',
#        'SanDisk Parchment Paper, Recycled',
#        'Stanley Pencil Sharpener, Water Color', 'Ames Mailers, Recycled',
#        'Harbour Creations Round Labels, 5000 Label Set', 'Xerox 1947',
#        'Xerox 1990', 'Harbour Creations Shipping Labels, Adjustable',
#        'Xerox 1898', 'SAFCO Executive Leather Armchair, Black',
#        'KitchenAid Refrigerator, Silver',
#        'Brother DCP1000 Digital 3 in 1 Multifunction Machine',
#        'Hoover Microwave, Red', 'Cisco Signal Booster, Cordless',
#        'HP Ink, Color', 'Apple Office Telephone, Full Size',
#        'Tenex Photo Frame, Duo Pack', 'Acme Letter Opener, Serrated',
#        'Hon Rocking Chair, Red', 'Stiletto Scissors, Steel',
#        'Memorex Router, Erganomic', 'Epson Phone, Wireless',
#        'Boston Sketch Pad, Easy-Erase',
#        'Belkin 6 Outlet Metallic Surge Strip',
#        'BIC Pencil Sharpener, Easy-Erase',
#        'Harbour Creations Shipping Labels, 5000 Label Set',
#        'Stockwell Push Pins, 12 Pack', 'KitchenAid Stove, Red',
#        'Sauder Stackable Bookrack, Pine',
#        'Lesro Wood Table, Adjustable Height',
#        'Hot File 7-Pocket, Floor Stand', 'Brother Ink, Laser',
#        'Hon Swivel Stool, Black', 'Tenex File Cart, Blue',
#        'Fiskars Trimmer, Easy Grip',
#        'Office Star Rocking Chair, Set of Two',
#        'Mophie Juice Pack Helium for iPhone', 'Belkin Router, Bluetooth',
#        'Epson Phone, Durable', 'Belkin Mouse, Erganomic',
#        'Barricks Training Table, Rectangular',
#        'Fiskars Shears, Easy Grip', 'Hoover Toaster, Red',
#        'Eaton Cards & Envelopes, Recycled', 'Eldon Trays, Wire Frame',
#        'Ibico Binder Covers, Recycled', 'Tenex Stacking Tray, Durable'],
#       dtype='<U90')

# %%
def ngrams_analyzer(string):
        string = re.sub(r'[,-./]', r'', string)
        ngrams = zip(*[string[i:] for i in range(5)]) #N-gram length
        return [''.join(ngram) for ngram in ngrams]

# %%
#constructing vectorizer
vectorizer=TfidfVectorizer(analyzer=ngrams_analyzer)

# %%
#Build the matrix
tfidf_matrix=vectorizer.fit_transform(vals)

# %%
tfidf_matrix[:10,:]
# Out:
# <10x4062 sparse matrix of type '<class 'numpy.float64'>'
# 	with 239 stored elements in Compressed Sparse Row format>

# %%
cosine_matrix = awesome_cossim_topn(tfidf_matrix, tfidf_matrix.transpose(), vals.size,0.25)

# %%
# Instaniate our lookup hash table
group_lookup = {}

# %%
def find_group(row, col):
    # If either the row or the col string have already been given
    # a group, return that group. Otherwise return none
    if row in group_lookup:
        return group_lookup[row]
    elif col in group_lookup:
        return group_lookup[col]
    else:
        return None

# %%
def add_vals_to_lookup(group, row, col):
    # Once we know the group name, set it as the value
    # for both strings in the group_lookup
    group_lookup[row] = group
    group_lookup[col] = group

# %%
def add_pair_to_lookup(row, col):
    # in this function we'll add both the row and the col to the lookup
    group = find_group(row, col)  # first, see if one has already been added
    if group is not None:
        # if we already know the group, make sure both row and col are in lookup
        add_vals_to_lookup(group, row, col)
    else:
        # if we get here, we need to add a new group.
        # The name is arbitrary, so just make it the row
        add_vals_to_lookup(row, row, col)

# %%
# Build a coordinate matrix
coo_matrix = cosine_matrix.tocoo()

# %%
coo_matrix
# Out:
# <413x413 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2563 stored elements in COOrdinate format>

# %%
for row, col in zip(coo_matrix.row, coo_matrix.col):
    if row != col:
        add_pair_to_lookup(vals[row], vals[col])

df['Group'] = df['ProductName'].map(group_lookup).fillna(df['ProductName'])

# %%
group_lookup
# Out:
# {'Tenex Lockers, Blue': 'Tenex Box, Single Width',
#  'Tenex Lockers, Single Width': 'Tenex Box, Single Width',
#  'Rogers Lockers, Wire Frame': 'Tenex Box, Single Width',
#  'Fellowes Lockers, Wire Frame': 'Tenex Box, Single Width',
#  'Fellowes Lockers, Single Width': 'Tenex Box, Single Width',
#  'Fellowes Lockers, Industrial': 'Tenex Box, Single Width',
#  'Acme Trimmer, High Speed': 'Acme Scissors, Easy Grip',
#  'Acme Trimmer, Steel': 'Acme Trimmer, High Speed',
#  'Acme Box Cutter, High Speed': 'Acme Scissors, Easy Grip',
#  'Kleencut Ruler, High Speed': 'Acme Scissors, Easy Grip',
#  'Acme Scissors, High Speed': 'Acme Scissors, Easy Grip',
#  'Stiletto Shears, High Speed': 'Acme Scissors, Easy Grip',
#  'Fiskars Trimmer, Serrated': 'Acme Trimmer, High Speed',
#  'Tenex Box, Single Width': 'Tenex Box, Single Width',
#  'Rogers Box, Single Width': 'Tenex Box, Single Width',
#  'Eldon Box, Single Width': 'Tenex Box, Single Width',
#  'Fellowes Box, Single Width': 'Tenex Box, Single Width',
#  'Tenex Trays, Single Width': 'Tenex Box, Single Width',
#  'Tenex Folders, Single Width': 'Tenex Box, Single Width',
#  'Tenex Box, Wire Frame': 'Tenex Box, Single Width',
#  'Eldon Shelving, Single Width': 'Tenex Box, Single Width',
#  'Smead Shelving, Single Width': 'Tenex Box, Single Width',
#  'Smead Folders, Single Width': 'Tenex Box, Single Width',
#  'Rogers Shelving, Single Width': 'Tenex Box, Single Width',
#  'Eldon File Cart, Single Width': 'Tenex Box, Single Width',
#  'Smead File Cart, Single Width': 'Tenex Box, Single Width',
#  'Fellowes Shelving, Single Width': 'Tenex Box, Single Width',
#  'Rogers File Cart, Single Width': 'Tenex Box, Single Width',
#  'Enermax Note Cards, Premium': 'Enermax Note Cards, Premium',
#  'Xerox Note Cards, Premium': 'Enermax Note Cards, Premium',
#  'Eaton Note Cards, Premium': 'Enermax Note Cards, Premium',
#  'Eaton Note Cards, 8.5 x 11': 'Enermax Note Cards, Premium',
#  'Eldon Light Bulb, Duo Pack': 'Rubbermaid Stacking Tray, Durable',
#  'Rubbermaid Light Bulb, Duo Pack': 'Rubbermaid Stacking Tray, Durable',
#  'Rubbermaid Light Bulb, Black': 'Rubbermaid Stacking Tray, Durable',
#  'Eaton Computer Printout Paper, 8.5 x 11': 'Eaton Computer Printout Paper, 8.5 x 11',
#  'Xerox Computer Printout Paper, 8.5 x 11': 'Eaton Computer Printout Paper, 8.5 x 11',
#  'Brother Personal Copier, Laser': 'Brother Personal Copier, Laser',
#  'Canon Personal Copier, Color': 'Brother Personal Copier, Laser',
#  'Hewlett Personal Copier, Digital': 'Brother Personal Copier, Laser',
#  'Hewlett Fax and Copier, Laser': 'Brother Personal Copier, Laser',
#  'Brother Fax and Copier, Color': 'Brother Personal Copier, Laser',
#  'Brother Ink, Laser': 'Brother Personal Copier, Laser',
#  'Fellowes Shelving, Wire Frame': 'Tenex Box, Single Width',
#  'Fellowes File Cart, Wire Frame': 'Tenex Box, Single Width',
#  'Rogers Trays, Wire Frame': 'Tenex Box, Single Width',
#  'Eldon Trays, Wire Frame': 'Tenex Box, Single Width',
#  'Rogers Box, Wire Frame': 'Tenex Box, Single Width',
#  'Smead Box, Wire Frame': 'Tenex Box, Single Width',
#  'KitchenAid Coffee Grinder, Red': 'KitchenAid Coffee Grinder, Red',
#  'KitchenAid Coffee Grinder, Silver': 'KitchenAid Coffee Grinder, Red',
#  'Hoover Coffee Grinder, White': 'KitchenAid Coffee Grinder, Red',
#  'Breville Coffee Grinder, Silver': 'KitchenAid Coffee Grinder, Red',
#  'KitchenAid Stove, Red': 'KitchenAid Coffee Grinder, Red',
#  'KitchenAid Stove, Black': 'KitchenAid Coffee Grinder, Red',
#  'KitchenAid Refrigerator, Silver': 'KitchenAid Coffee Grinder, Red',
#  'Hamilton Beach Refrigerator, Silver': 'KitchenAid Coffee Grinder, Red',
#  'Hamilton Beach Toaster, Black': 'KitchenAid Coffee Grinder, Red',
#  'Advantus Photo Frame, Erganomic': 'Advantus Photo Frame, Erganomic',
#  'Tenex Photo Frame, Duo Pack': 'Advantus Photo Frame, Erganomic',
#  'Advantus Paper Clips, Metal': 'OIC Push Pins, Assorted Sizes',
#  'Binney & Smith Pencil Sharpener, Easy-Erase': 'BIC Markers, Easy-Erase',
#  'Binney & Smith Pens, Easy-Erase': 'BIC Highlighters, Blue',
#  'BIC Pencil Sharpener, Easy-Erase': 'BIC Markers, Easy-Erase',
#  'Sanford Pencil Sharpener, Easy-Erase': 'BIC Markers, Easy-Erase',
#  'Stanley Pencil Sharpener, Easy-Erase': 'BIC Markers, Easy-Erase',
#  'Binney & Smith Highlighters, Blue': 'BIC Markers, Easy-Erase',
#  'BIC Pencil Sharpener, Fluorescent': 'BIC Markers, Easy-Erase',
#  'Boston Pencil Sharpener, Water Color': 'BIC Markers, Easy-Erase',
#  'Sanford Pencil Sharpener, Water Color': 'BIC Markers, Easy-Erase',
#  'Stanley Pencil Sharpener, Water Color': 'BIC Markers, Easy-Erase',
#  'Boston Pencil Sharpener, Fluorescent': 'BIC Markers, Easy-Erase',
#  'Memorex Memory Card, USB': 'Belkin Keyboard, USB',
#  'Memorex Memory Card, Erganomic': 'Belkin Keyboard, USB',
#  'SanDisk Memory Card, Erganomic': 'Jiffy Clasp Envelope, Recycled',
#  'SanDisk Memory Card, Bluetooth': 'Jiffy Clasp Envelope, Recycled',
#  'Sanford Highlighters, Water Color': 'BIC Markers, Easy-Erase',
#  'Sanford Pens, Fluorescent': 'BIC Markers, Easy-Erase',
#  'Hunt BOSTON Vista Battery-Operated Pencil Sharpener, Black': 'BIC Markers, Easy-Erase',
#  'Model L Table or Wall-Mount Pencil Sharpener': 'BIC Markers, Easy-Erase',
#  'BIC Markers, Water Color': 'BIC Markers, Easy-Erase',
#  'BIC Canvas, Water Color': 'BIC Markers, Easy-Erase',
#  'Wilson Jones Hole Reinforcements, Economy': 'Wilson Jones Hole Reinforcements, Economy',
#  'Wilson Jones Hole Reinforcements, Clear': 'Wilson Jones Hole Reinforcements, Economy',
#  'Ibico Hole Reinforcements, Economy': 'Wilson Jones Hole Reinforcements, Economy',
#  'Cardinal Hole Reinforcements, Economy': 'Wilson Jones Hole Reinforcements, Economy',
#  'Ibico Hole Reinforcements, Clear': 'Wilson Jones Hole Reinforcements, Economy',
#  'Acco Hole Reinforcements, Recycled': 'Wilson Jones Hole Reinforcements, Economy',
#  'Avery Hole Reinforcements, Recycled': 'Wilson Jones Hole Reinforcements, Economy',
#  'Avery Hole Reinforcements, Durable': 'Wilson Jones Hole Reinforcements, Economy',
#  'Cardinal Hole Reinforcements, Durable': 'Wilson Jones Hole Reinforcements, Economy',
#  'Wilson Jones 3-Hole Punch, Economy': 'Wilson Jones Hole Reinforcements, Economy',
#  'Wilson Jones 3-Hole Punch, Clear': 'Wilson Jones Hole Reinforcements, Economy',
#  'Wilson Jones Index Tab, Durable': 'Wilson Jones Hole Reinforcements, Economy',
#  'Wilson Jones Binding Machine, Recycled': 'Wilson Jones Hole Reinforcements, Economy',
#  'Smead File Folder Labels, Adjustable': 'Hon Swivel Stool, Red',
#  'Harbour Creations File Folder Labels, Adjustable': 'Hon Swivel Stool, Red',
#  'Smead Shipping Labels, Adjustable': 'Hon Swivel Stool, Red',
#  'Hon Round Labels, Adjustable': 'Hon Swivel Stool, Red',
#  'Avery Round Labels, Adjustable': 'Hon Swivel Stool, Red',
#  'Harbour Creations Shipping Labels, Adjustable': 'Hon Swivel Stool, Red',
#  'GlobeWeis Peel and Seal, Set of 50': 'GlobeWeis Peel and Seal, Set of 50',
#  'Ames Peel and Seal, Set of 50': 'GlobeWeis Peel and Seal, Set of 50',
#  'Ames Peel and Seal, Recycled': 'GlobeWeis Peel and Seal, Set of 50',
#  'Kraft Peel and Seal, Security-Tint': 'GlobeWeis Peel and Seal, Set of 50',
#  'Cameo Peel and Seal, Security-Tint': 'GlobeWeis Peel and Seal, Set of 50',
#  'Kraft Peel and Seal, Recycled': 'GlobeWeis Peel and Seal, Set of 50',
#  'Jiffy Peel and Seal, with clear poly window': 'GlobeWeis Peel and Seal, Set of 50',
#  'Fellowes File Cart, Industrial': 'Tenex Box, Single Width',
#  'Eldon File Cart, Industrial': 'Tenex Box, Single Width',
#  'Fellowes File Cart, Blue': 'Tenex Box, Single Width',
#  'Fellowes Shelving, Industrial': 'Tenex Box, Single Width',
#  'Eldon Folders, Industrial': 'Tenex Box, Single Width',
#  'Rogers Folders, Industrial': 'Tenex Box, Single Width',
#  'Tenex Shelving, Industrial': 'Tenex Box, Single Width',
#  'Eldon File Cart, Blue': 'Tenex Box, Single Width',
#  'Tenex File Cart, Blue': 'Tenex Box, Single Width',
#  'Fellowes Folders, Blue': 'Tenex Box, Single Width',
#  'Safco Classic Bookcase, Traditional': 'Safco Classic Bookcase, Traditional',
#  'Ikea Classic Bookcase, Traditional': 'Safco Classic Bookcase, Traditional',
#  'Sauder Classic Bookcase, Metal': 'Safco Classic Bookcase, Traditional',
#  'Safco Library with Doors, Traditional': 'Dania Library with Doors, Metal',
#  'Safco Floating Shelf Set, Traditional': 'Safco Classic Bookcase, Traditional',
#  'Logitech Router, Erganomic': 'Belkin Keyboard, USB',
#  'Belkin Router, Erganomic': 'Belkin Keyboard, USB',
#  'Memorex Router, Erganomic': 'Belkin Keyboard, USB',
#  'SanDisk Router, Erganomic': 'Belkin Keyboard, USB',
#  'Logitech Numeric Keypad, Erganomic': 'Enermax Mouse, Erganomic',
#  'Harbour Creations Bag Chairs, Red': 'Hon Swivel Stool, Red',
#  'Harbour Creations Steel Folding Chair': 'Hon Swivel Stool, Red',
#  'Harbour Creations Steel Folding Chair, Red': 'Hon Swivel Stool, Red',
#  'Harbour Creations Steel Folding Chair, Black': 'Hon Swivel Stool, Red',
#  'Harbour Creations Steel Folding Chair, Set of Two': 'Hon Swivel Stool, Red',
#  'Harbour Creations Swivel Stool, Black': 'Hon Swivel Stool, Red',
#  'Hon Bag Chairs, Black': 'Hon Swivel Stool, Red',
#  'Harbour Creations Round Labels, 5000 Label Set': 'Hon Swivel Stool, Red',
#  'Harbour Creations Round Labels, Alphabetical': 'Hon Swivel Stool, Red',
#  'Harbour Creations Shipping Labels, 5000 Label Set': 'Hon Swivel Stool, Red',
#  'Harbour Creations Executive Leather Armchair, Black': 'Hon Swivel Stool, Red',
#  'Novimex Bag Chairs, Adjustable': 'Hon Swivel Stool, Red',
#  'SAFCO Bag Chairs, Set of Two': 'Hon Swivel Stool, Red',
#  'Office Star Rocking Chair, Red': 'Hon Swivel Stool, Red',
#  'Office Star Rocking Chair, Set of Two': 'Hon Swivel Stool, Red',
#  'Hon Rocking Chair, Red': 'Hon Swivel Stool, Red',
#  'Hon Steel Folding Chair, Red': 'Hon Swivel Stool, Red',
#  'Office Star Executive Leather Armchair, Black': 'Hon Swivel Stool, Red',
#  'Office Star Executive Leather Armchair, Adjustable': 'Hon Swivel Stool, Red',
#  'Panasonic Receipt Printer, White': 'Panasonic Receipt Printer, White',
#  'Epson Receipt Printer, Wireless': 'Brother Personal Copier, Laser',
#  'StarTech Receipt Printer, Wireless': 'Brother Personal Copier, Laser',
#  'Konica Printer, White': 'Panasonic Receipt Printer, White',
#  'Okidata Printer, White': 'Panasonic Receipt Printer, White',
#  'Okidata Card Printer, White': 'Panasonic Receipt Printer, White',
#  'Panasonic Calculator, Red': 'Epson Calculator, Durable',
#  'Sharp Fax Machine, High-Speed': 'Sharp Fax Machine, High-Speed',
#  'Brother Fax Machine, Laser': 'Brother Personal Copier, Laser',
#  'HP Ink, High-Speed': 'Sharp Fax Machine, High-Speed',
#  'BIC Sketch Pad, Blue': 'BIC Sketch Pad, Blue',
#  'Boston Sketch Pad, Easy-Erase': 'BIC Sketch Pad, Blue',
#  'SAFCO Steel Folding Chair, Black': 'Hon Swivel Stool, Red',
#  'Eldon Shelving, Blue': 'Tenex Box, Single Width',
#  'Smead Shelving, Blue': 'Tenex Box, Single Width',
#  'Apple Speaker Phone, with Caller ID': 'Cisco Signal Booster, Full Size',
#  'Apple Speaker Phone, Full Size': 'Apple Speaker Phone, with Caller ID',
#  'Samsung Speaker Phone, Cordless': 'Apple Speaker Phone, with Caller ID',
#  'Motorola Audio Dock, with Caller ID': 'Apple Speaker Phone, with Caller ID',
#  'BIC Markers, Easy-Erase': 'BIC Markers, Easy-Erase',
#  'Stanley Markers, Easy-Erase': 'BIC Markers, Easy-Erase',
#  'Stanley Canvas, Easy-Erase': 'BIC Markers, Easy-Erase',
#  'Stanley Markers, Water Color': 'BIC Markers, Easy-Erase',
#  'Konica Phone, White': 'Panasonic Receipt Printer, White',
#  'Konica Card Printer, Red': 'Panasonic Receipt Printer, White',
#  'Tenex Clock, Black': '9-3/4 Diameter Round Wall Clock',
#  'Linden 10" Round Wall Clock, Black': '9-3/4 Diameter Round Wall Clock',
#  'Hon Swivel Stool, Red': 'Hon Swivel Stool, Red',
#  'Hon Swivel Stool, Black': 'Hon Swivel Stool, Red',
#  'Belkin Keyboard, USB': 'Belkin Keyboard, USB',
#  'Enermax Keyboard, Erganomic': 'Belkin Keyboard, USB',
#  'Enermax Keyboard, Bluetooth': 'Belkin Keyboard, USB',
#  'Memorex Keyboard, Bluetooth': 'Belkin Keyboard, USB',
#  'Cisco Signal Booster, Full Size': 'Cisco Signal Booster, Full Size',
#  'Apple Signal Booster, Full Size': 'Cisco Signal Booster, Full Size',
#  'Cisco Signal Booster, Cordless': 'Cisco Signal Booster, Full Size',
#  'Motorola Signal Booster, Cordless': 'Cisco Signal Booster, Full Size',
#  'Cisco Smart Phone, Full Size': 'Apple Speaker Phone, with Caller ID',
#  'Cisco Headset, Full Size': 'Apple Speaker Phone, with Caller ID',
#  'Cisco Audio Dock, Full Size': 'Apple Speaker Phone, with Caller ID',
#  'Dania Floating Shelf Set, Traditional': 'Safco Classic Bookcase, Traditional',
#  'Bush Floating Shelf Set, Mobile': 'Safco Classic Bookcase, Traditional',
#  'Stanley Canvas, Blue': 'BIC Markers, Easy-Erase',
#  'Stanley Canvas, Water Color': 'BIC Markers, Easy-Erase',
#  'Acco 3-Hole Punch, Recycled': 'Wilson Jones Hole Reinforcements, Economy',
#  'Avery 3-Hole Punch, Recycled': 'Wilson Jones Hole Reinforcements, Economy',
#  'Cardinal 3-Hole Punch, Recycled': 'Wilson Jones Hole Reinforcements, Economy',
#  'Ibico 3-Hole Punch, Clear': 'Wilson Jones Hole Reinforcements, Economy',
#  'Cardinal 3-Hole Punch, Economy': 'Wilson Jones Hole Reinforcements, Economy',
#  'Epson Calculator, Durable': 'Brother Personal Copier, Laser',
#  'Epson Calculator, Wireless': 'Brother Personal Copier, Laser',
#  'StarTech Calculator, Red': 'Epson Calculator, Durable',
#  'Epson Phone, Durable': 'Brother Personal Copier, Laser',
#  'Acme Scissors, Easy Grip': 'Acme Trimmer, High Speed',
#  'Acme Scissors, Serrated': 'Acme Scissors, Easy Grip',
#  'Elite Shears, Easy Grip': 'Acme Trimmer, High Speed',
#  'Fiskars Shears, Easy Grip': 'Acme Trimmer, High Speed',
#  'Stiletto Scissors, Steel': 'Acme Scissors, Easy Grip',
#  'Fiskars Trimmer, Easy Grip': 'Acme Trimmer, High Speed',
#  'Xerox Parchment Paper, Premium': 'Xerox Parchment Paper, Premium',
#  'SanDisk Parchment Paper, Recycled': 'Xerox Parchment Paper, Premium',
#  'Array Parchment Paper, Assorted Colors': 'Xerox Parchment Paper, Premium',
#  'Southworth Parchment Paper & Envelopes': 'Xerox Parchment Paper, Premium',
#  'Sanford Canvas, Fluorescent': 'BIC Markers, Easy-Erase',
#  'Sanford Highlighters, Fluorescent': 'BIC Markers, Easy-Erase',
#  'Stanley Markers, Fluorescent': 'BIC Markers, Easy-Erase',
#  'OIC Push Pins, Assorted Sizes': 'OIC Push Pins, Assorted Sizes',
#  'Stockwell Push Pins, Assorted Sizes': 'OIC Push Pins, Assorted Sizes',
#  'Accos Paper Clips, Assorted Sizes': 'OIC Push Pins, Assorted Sizes',
#  'Advantus Rubber Bands, Assorted Sizes': 'OIC Push Pins, Assorted Sizes',
#  'Stockwell Thumb Tacks, Assorted Sizes': 'OIC Push Pins, Assorted Sizes',
#  'Stockwell Push Pins, 12 Pack': 'OIC Push Pins, Assorted Sizes',
#  'Hon Shipping Labels, 5000 Label Set': 'Hon Swivel Stool, Red',
#  'Avery Shipping Labels, 5000 Label Set': 'Hon Swivel Stool, Red',
#  'Avery Color Coded Labels, 5000 Label Set': 'Hon Swivel Stool, Red',
#  'Avery Legal Exhibit Labels, 5000 Label Set': 'Hon Swivel Stool, Red',
#  'Hon Shipping Labels, Laser Printer Compatible': 'Hon Swivel Stool, Red',
#  'Avery Shipping Labels, Alphabetical': 'Hon Swivel Stool, Red',
#  'Avery Shipping Labels, Laser Printer Compatible': 'Hon Swivel Stool, Red',
#  'Novimex Chairmat, Adjustable': 'Novimex Chairmat, Red',
#  'Plymouth Boxed Rubber Bands by Plymouth': 'Plymouth Boxed Rubber Bands by Plymouth',
#  'Sterling Rubber Bands by Alliance': 'OIC Push Pins, Assorted Sizes',
#  'OIC Rubber Bands, 12 Pack': 'OIC Push Pins, Assorted Sizes',
#  'Hon Round Labels, Laser Printer Compatible': 'Hon Round Labels, Laser Printer Compatible',
#  'Avery Round Labels, Laser Printer Compatible': 'Hon Round Labels, Laser Printer Compatible',
#  'Ibico Index Tab, Clear': 'Wilson Jones Hole Reinforcements, Economy',
#  'Acco Index Tab, Clear': 'Wilson Jones Hole Reinforcements, Economy',
#  'Ibico Index Tab, Durable': 'Wilson Jones Hole Reinforcements, Economy',
#  'Hoover Toaster, Silver': 'Hoover Toaster, Silver',
#  'Hoover Toaster, Red': 'Hoover Toaster, Silver',
#  'Cuisinart Toaster, Red': 'Hoover Toaster, Silver',
#  'Acco Binding Machine, Recycled': 'Wilson Jones Hole Reinforcements, Economy',
#  'Avery Binding Machine, Recycled': 'Wilson Jones Hole Reinforcements, Economy',
#  'Ibico Binding Machine, Recycled': 'Wilson Jones Hole Reinforcements, Economy',
#  'Cardinal Binding Machine, Recycled': 'Wilson Jones Hole Reinforcements, Economy',
#  'Avery Binding Machine, Durable': 'Brother Personal Copier, Laser',
#  'Acco Binding Machine, Economy': 'Wilson Jones Hole Reinforcements, Economy',
#  'Cardinal Binding Machine, Clear': 'Wilson Jones Hole Reinforcements, Economy',
#  'Cardinal Binding Machine, Durable': 'Brother Personal Copier, Laser',
#  'Wilson Jones Hanging Recycled Pressboard Data Binders': 'Wilson Jones Hole Reinforcements, Economy',
#  'Ikea 3-Shelf Cabinet, Metal': 'Ikea 3-Shelf Cabinet, Metal',
#  'Ikea 3-Shelf Cabinet, Pine': 'Ikea 3-Shelf Cabinet, Metal',
#  'Boston Highlighters, Water Color': 'BIC Markers, Easy-Erase',
#  'Samsung Audio Dock, VoIP': 'Apple Speaker Phone, with Caller ID',
#  'Cardinal Binder, Clear': 'Wilson Jones Hole Reinforcements, Economy',
#  'Cardinal Binder Covers, Clear': 'Wilson Jones Hole Reinforcements, Economy',
#  'Cardinal Binder Covers, Economy': 'Wilson Jones Hole Reinforcements, Economy',
#  'Cuisinart Blender, Black': 'Hoover Toaster, Silver',
#  'Cuisinart Microwave, Silver': 'Hoover Toaster, Silver',
#  'SanDisk Flash Drive, Programmable': 'SanDisk Flash Drive, Programmable',
#  'Belkin Flash Drive, Programmable': 'SanDisk Flash Drive, Programmable',
#  'Enermax Mouse, Programmable': 'SanDisk Flash Drive, Programmable',
#  'Memorex Router, Programmable': 'Belkin Keyboard, USB',
#  'Memorex Numeric Keypad, Erganomic': 'Belkin Keyboard, USB',
#  'Novimex Chairmat, Red': 'Novimex Chairmat, Red',
#  'Novimex Chairmat, Black': 'Novimex Chairmat, Red',
#  'Rogers Trays, Blue': 'Tenex Box, Single Width',
#  'Rubbermaid Stacking Tray, Durable': 'Rubbermaid Stacking Tray, Durable',
#  'Tenex Stacking Tray, Durable': 'Rubbermaid Stacking Tray, Durable',
#  'Rubbermaid Frame, Black': 'Rubbermaid Stacking Tray, Durable',
#  'Avery 490': 'Avery 490',
#  'Avery 475': 'Avery 490',
#  'Ibico Binder Covers, Clear': 'Wilson Jones Hole Reinforcements, Economy',
#  'Ibico Binder Covers, Recycled': 'Wilson Jones Hole Reinforcements, Economy',
#  'Acco Binder Covers, Durable': 'Wilson Jones Hole Reinforcements, Economy',
#  'Avery Binder Covers, Economy': 'Wilson Jones Hole Reinforcements, Economy',
#  'Pressboard Data Binder, Crimson, 12" X 8 1/2"': 'Wilson Jones Hole Reinforcements, Economy',
#  'Zipper Ring Binder Pockets': 'Wilson Jones Heavy-Duty Casebound Ring Binders with Metal Hinges',
#  'Prestige Round Ring Binders': 'Wilson Jones Heavy-Duty Casebound Ring Binders with Metal Hinges',
#  'Jiffy Clasp Envelope, Recycled': 'Jiffy Clasp Envelope, Recycled',
#  'Kraft Manila Envelope, Recycled': 'Jiffy Clasp Envelope, Recycled',
#  'Kraft Clasp Envelope, with clear poly window': 'GlobeWeis Peel and Seal, Set of 50',
#  'Jiffy Business Envelopes, Recycled': 'Jiffy Clasp Envelope, Recycled',
#  'Eaton Cards & Envelopes, Recycled': 'Jiffy Clasp Envelope, Recycled',
#  'Ikea Corner Shelving, Traditional': 'Safco Classic Bookcase, Traditional',
#  "Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room": "Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room",
#  'Honeywell Quietcare HEPA Air Cleaner': "Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room",
#  'Enermax Numeric Keypad, Bluetooth': 'Enermax Mouse, Erganomic',
#  'Enermax Numeric Keypad, Erganomic': 'Enermax Mouse, Erganomic',
#  'Enermax Mouse, Bluetooth': 'Enermax Mouse, Erganomic',
#  'Enermax Router, Bluetooth': 'Enermax Mouse, Erganomic',
#  'Dania Library with Doors, Metal': 'Dania Library with Doors, Metal',
#  'Ikea Library with Doors, Pine': 'Dania Library with Doors, Metal',
#  'Bush Library with Doors, Traditional': 'Dania Library with Doors, Metal',
#  'SanDisk Mouse, Bluetooth': 'Enermax Mouse, Erganomic',
#  'SanDisk Memo Slips, Multicolor': 'Jiffy Clasp Envelope, Recycled',
#  'Enermax Aurora Lite Keyboard': 'Belkin Keyboard, USB',
#  'Apple Office Telephone, Full Size': 'Apple Speaker Phone, with Caller ID',
#  'Enermax Mouse, Erganomic': 'Belkin Keyboard, USB',
#  'Belkin Mouse, Erganomic': 'Belkin Keyboard, USB',
#  'Boston Heavy-Duty Trimline Electric Pencil Sharpeners': 'BIC Markers, Easy-Erase',
#  'BOSTON Model 1800 Electric Pencil Sharpeners, Putty/Woodgrain': 'Boston Heavy-Duty Trimline Electric Pencil Sharpeners',
#  'Wilson Jones Heavy-Duty Casebound Ring Binders with Metal Hinges': 'Wilson Jones Heavy-Duty Casebound Ring Binders with Metal Hinges',
#  'Wilson Jones data.warehouse D-Ring Binders with DublLock': 'Wilson Jones Heavy-Duty Casebound Ring Binders with Metal Hinges',
#  'Smead Trays, Blue': 'Tenex Box, Single Width',
#  'Adams Telephone Message Book w/Frequently-Called Numbers Space, 400 Messages per Book': 'Adams Telephone Message Book w/Frequently-Called Numbers Space, 400 Messages per Book',
#  'Eaton Message Books, Recycled': 'Adams Telephone Message Book w/Frequently-Called Numbers Space, 400 Messages per Book',
#  'Enermax Message Books, 8.5 x 11': 'Adams Telephone Message Book w/Frequently-Called Numbers Space, 400 Messages per Book',
#  'Kraft Interoffice Envelope, with clear poly window': 'GlobeWeis Peel and Seal, Set of 50',
#  'Xerox 205': 'Xerox 205',
#  'Xerox 214': 'Xerox 205',
#  'Xerox 216': 'Xerox 205',
#  'Avery Binder, Recycled': 'Wilson Jones Hole Reinforcements, Economy',
#  'Advantus Staples, Bulk Pack': 'Advantus Staples, Bulk Pack',
#  'Staples': 'Advantus Staples, Bulk Pack',
#  'Lesro Round Table, Rectangular': 'Lesro Round Table, Rectangular',
#  'Barricks Training Table, Rectangular': 'Lesro Round Table, Rectangular',
#  'Chromcraft Computer Table, Fully Assembled': 'Chromcraft Computer Table, Fully Assembled',
#  'Bevis Computer Table, Fully Assembled': 'Chromcraft Computer Table, Fully Assembled',
#  'Bevis Computer Table, Adjustable Height': 'Chromcraft Computer Table, Fully Assembled',
#  'BIC Highlighters, Blue': 'BIC Markers, Easy-Erase',
#  'Sanford Highlighters, Blue': 'BIC Markers, Easy-Erase',
#  'Xerox Cards & Envelopes, Multicolor': 'Jiffy Clasp Envelope, Recycled',
#  'Eaton Cards & Envelopes, 8.5 x 11': 'Jiffy Clasp Envelope, Recycled',
#  'Xerox Memo Slips, Multicolor': 'Jiffy Clasp Envelope, Recycled',
#  'Eldon Door Stop, Erganomic': 'Eldon Door Stop, Erganomic',
#  'Tenex Door Stop, Erganomic': 'Eldon Door Stop, Erganomic',
#  'Deflect-O Door Stop, Black': 'Eldon Door Stop, Erganomic',
#  'Master Caster Door Stop, Brown': 'Eldon Door Stop, Erganomic',
#  'Avery Durable Binders': 'Wilson Jones Hole Reinforcements, Economy',
#  'HP Fax and Copier, Color': 'Brother Personal Copier, Laser',
#  'HP Fax and Copier, Digital': 'Brother Personal Copier, Laser',
#  'SAFCO Executive Leather Armchair, Adjustable': 'Hon Swivel Stool, Red',
#  'SAFCO Executive Leather Armchair, Red': 'Hon Swivel Stool, Red',
#  'SAFCO Executive Leather Armchair, Black': 'Hon Swivel Stool, Red',
#  'Novimex Executive Leather Armchair, Black': 'Hon Swivel Stool, Red',
#  'Hoover Microwave, Red': 'Hoover Toaster, Silver',
#  'OIC Paper Clips, 12 Pack': 'OIC Push Pins, Assorted Sizes',
#  'Acco Clips to Go Binder Clips, 24 Clips in Two Sizes': 'OIC Push Pins, Assorted Sizes',
#  'Stiletto Box Cutter, Serrated': 'Acme Trimmer, High Speed',
#  'Elite Ruler, Serrated': 'Acme Trimmer, High Speed',
#  'Acme Letter Opener, Serrated': 'Acme Trimmer, High Speed',
#  'Xerox 1916': 'Xerox 1916',
#  'Xerox 1990': 'Xerox 1916',
#  'Xerox 1947': 'Xerox 1916',
#  'Xerox 1971': 'Xerox 1916',
#  'Xerox 1934': 'Xerox 1916',
#  'Xerox 1898': 'Xerox 1916',
#  '9-3/4 Diameter Round Wall Clock': '9-3/4 Diameter Round Wall Clock',
#  'Howard Miller 13" Diameter Pewter Finish Round Wall Clock': '9-3/4 Diameter Round Wall Clock',
#  'Belkin Router, Bluetooth': 'Enermax Mouse, Erganomic',
#  'Epson Inkjet, Wireless': 'Brother Personal Copier, Laser',
#  'Okidata Inkjet, Wireless': 'Epson Inkjet, Wireless',
#  'Epson Phone, Wireless': 'Brother Personal Copier, Laser',
#  'Deflect-O Frame, Black': 'Rubbermaid Stacking Tray, Durable',
#  'Acco Economy Flexible Poly Round Ring Binder': 'Wilson Jones Heavy-Duty Casebound Ring Binders with Metal Hinges',
#  'Brother Wireless Fax, Laser': 'Brother Personal Copier, Laser',
#  'Canon Copy Machine, Color': 'Canon Copy Machine, Color',
#  'Hewlett Copy Machine, Color': 'Canon Copy Machine, Color',
#  'Canon Ink, Laser': 'Brother Personal Copier, Laser',
#  'Samsung Smart Phone, Cordless': 'Apple Speaker Phone, with Caller ID',
#  'Lesro Wood Table, Adjustable Height': 'Chromcraft Computer Table, Fully Assembled',
#  'Canon Wireless Fax, Digital': 'Brother Personal Copier, Laser',
#  'Sauder Corner Shelving, Traditional': 'Safco Classic Bookcase, Traditional',
#  'Ikea Stackable Bookrack, Mobile': 'Ikea Stackable Bookrack, Mobile',
#  'Safco Stackable Bookrack, Pine': 'Ikea Stackable Bookrack, Mobile',
#  'Sauder Stackable Bookrack, Pine': 'Ikea Stackable Bookrack, Mobile',
#  'Motorola Headset, Full Size': 'Apple Speaker Phone, with Caller ID',
#  'HP Ink, Color': 'Sharp Fax Machine, High-Speed',
#  'Ames Mailers, Recycled': 'Wilson Jones Hole Reinforcements, Economy'}

# %%
df.groupby(['ProductName','Group']).count()['ProductID']
# Out:
# ProductName                                      Group
# 3M Hangers With Command Adhesive                 3M Hangers With Command Adhesive                                      1
# 9-3/4 Diameter Round Wall Clock                  9-3/4 Diameter Round Wall Clock                                      16
# Acco 3-Hole Punch, Recycled                      Wilson Jones Hole Reinforcements, Economy                             2
# Acco 6 Outlet Guardian Premium Surge Suppressor  Acco 6 Outlet Guardian Premium Surge Suppressor                       1
# Acco Binder Covers, Durable                      Wilson Jones Hole Reinforcements, Economy                           135
#                                                                                                                     ...
# Xerox Computer Printout Paper, 8.5 x 11          Eaton Computer Printout Paper, 8.5 x 11                               5
# Xerox Memo Slips, Multicolor                     Jiffy Clasp Envelope, Recycled                                       20
# Xerox Note Cards, Premium                        Enermax Note Cards, Premium                                         143
# Xerox Parchment Paper, Premium                   Xerox Parchment Paper, Premium                                      322
# Zipper Ring Binder Pockets                       Wilson Jones Heavy-Duty Casebound Ring Binders with Metal Hinges     74
# Name: ProductID, Length: 413, dtype: int64

# %%
df[df["ProductName"]=='Acco Binder Covers, Durable'].groupby(['Group']).count()
# Out:
#                                            Row ID  Order ID  Order Date  \
# Group
# Wilson Jones Hole Reinforcements, Economy     135       135         135
#
#                                            Ship Date  Ship Mode  Customer ID  \
# Group
# Wilson Jones Hole Reinforcements, Economy        135        135          135
#
#                                            Customer Name  Segment  City  \
# Group
# Wilson Jones Hole Reinforcements, Economy            135      135   135
#
#                                            State  ...  Category  Sub-Category  \
# Group                                             ...
# Wilson Jones Hole Reinforcements, Economy    135  ...       135           135
#
#                                            ProductName  Sales  Quantity  \
# Group
# Wilson Jones Hole Reinforcements, Economy          135    135       135
#
#                                            Discount  Profit  Shipping Cost  \
# Group
# Wilson Jones Hole Reinforcements, Economy       135     135            135
#
#                                            Order Priority  Rating
# Group
# Wilson Jones Hole Reinforcements, Economy             135     135
#
# [1 rows x 25 columns]

# %%
df[df["Group"]=='Wilson Jones Hole Reinforcements, Economy'].groupby(['ProductName']).count()
# Out:
#                                                     Row ID  Order ID  \
# ProductName
# Acco 3-Hole Punch, Recycled                              2         2
# Acco Binder Covers, Durable                            135       135
# Acco Binding Machine, Economy                           21        21
# Acco Binding Machine, Recycled                         123       123
# Acco Hole Reinforcements, Recycled                     362       362
# Acco Index Tab, Clear                                   33        33
# Ames Mailers, Recycled                                  12        12
# Avery 3-Hole Punch, Recycled                            55        55
# Avery Binder Covers, Economy                             1         1
# Avery Binder, Recycled                                  52        52
# Avery Binding Machine, Recycled                         12        12
# Avery Durable Binders                                  227       227
# Avery Hole Reinforcements, Durable                     159       159
# Avery Hole Reinforcements, Recycled                     58        58
# Cardinal 3-Hole Punch, Economy                          47        47
# Cardinal 3-Hole Punch, Recycled                        126       126
# Cardinal Binder Covers, Clear                            2         2
# Cardinal Binder Covers, Economy                        422       422
# Cardinal Binder, Clear                                  28        28
# Cardinal Binding Machine, Clear                         32        32
# Cardinal Binding Machine, Recycled                      88        88
# Cardinal Hole Reinforcements, Durable                   41        41
# Cardinal Hole Reinforcements, Economy                  349       349
# Ibico 3-Hole Punch, Clear                              178       178
# Ibico Binder Covers, Clear                             385       385
# Ibico Binder Covers, Recycled                            1         1
# Ibico Binding Machine, Recycled                        199       199
# Ibico Hole Reinforcements, Clear                       558       558
# Ibico Hole Reinforcements, Economy                      76        76
# Ibico Index Tab, Clear                                  51        51
# Ibico Index Tab, Durable                                22        22
# Pressboard Data Binder, Crimson, 12" X 8 1/2"            9         9
# Wilson Jones 3-Hole Punch, Clear                        22        22
# Wilson Jones 3-Hole Punch, Economy                       1         1
# Wilson Jones Binding Machine, Recycled                  20        20
# Wilson Jones Hanging Recycled Pressboard Data B...     159       159
# Wilson Jones Hole Reinforcements, Clear                 69        69
# Wilson Jones Hole Reinforcements, Economy               84        84
# Wilson Jones Index Tab, Durable                          1         1
#
#                                                     Order Date  Ship Date  \
# ProductName
# Acco 3-Hole Punch, Recycled                                  2          2
# Acco Binder Covers, Durable                                135        135
# Acco Binding Machine, Economy                               21         21
# Acco Binding Machine, Recycled                             123        123
# Acco Hole Reinforcements, Recycled                         362        362
# Acco Index Tab, Clear                                       33         33
# Ames Mailers, Recycled                                      12         12
# Avery 3-Hole Punch, Recycled                                55         55
# Avery Binder Covers, Economy                                 1          1
# Avery Binder, Recycled                                      52         52
# Avery Binding Machine, Recycled                             12         12
# Avery Durable Binders                                      227        227
# Avery Hole Reinforcements, Durable                         159        159
# Avery Hole Reinforcements, Recycled                         58         58
# Cardinal 3-Hole Punch, Economy                              47         47
# Cardinal 3-Hole Punch, Recycled                            126        126
# Cardinal Binder Covers, Clear                                2          2
# Cardinal Binder Covers, Economy                            422        422
# Cardinal Binder, Clear                                      28         28
# Cardinal Binding Machine, Clear                             32         32
# Cardinal Binding Machine, Recycled                          88         88
# Cardinal Hole Reinforcements, Durable                       41         41
# Cardinal Hole Reinforcements, Economy                      349        349
# Ibico 3-Hole Punch, Clear                                  178        178
# Ibico Binder Covers, Clear                                 385        385
# Ibico Binder Covers, Recycled                                1          1
# Ibico Binding Machine, Recycled                            199        199
# Ibico Hole Reinforcements, Clear                           558        558
# Ibico Hole Reinforcements, Economy                          76         76
# Ibico Index Tab, Clear                                      51         51
# Ibico Index Tab, Durable                                    22         22
# Pressboard Data Binder, Crimson, 12" X 8 1/2"                9          9
# Wilson Jones 3-Hole Punch, Clear                            22         22
# Wilson Jones 3-Hole Punch, Economy                           1          1
# Wilson Jones Binding Machine, Recycled                      20         20
# Wilson Jones Hanging Recycled Pressboard Data B...         159        159
# Wilson Jones Hole Reinforcements, Clear                     69         69
# Wilson Jones Hole Reinforcements, Economy                   84         84
# Wilson Jones Index Tab, Durable                              1          1
#
#                                                     Ship Mode  Customer ID  \
# ProductName
# Acco 3-Hole Punch, Recycled                                 2            2
# Acco Binder Covers, Durable                               135          135
# Acco Binding Machine, Economy                              21           21
# Acco Binding Machine, Recycled                            123          123
# Acco Hole Reinforcements, Recycled                        362          362
# Acco Index Tab, Clear                                      33           33
# Ames Mailers, Recycled                                     12           12
# Avery 3-Hole Punch, Recycled                               55           55
# Avery Binder Covers, Economy                                1            1
# Avery Binder, Recycled                                     52           52
# Avery Binding Machine, Recycled                            12           12
# Avery Durable Binders                                     227          227
# Avery Hole Reinforcements, Durable                        159          159
# Avery Hole Reinforcements, Recycled                        58           58
# Cardinal 3-Hole Punch, Economy                             47           47
# Cardinal 3-Hole Punch, Recycled                           126          126
# Cardinal Binder Covers, Clear                               2            2
# Cardinal Binder Covers, Economy                           422          422
# Cardinal Binder, Clear                                     28           28
# Cardinal Binding Machine, Clear                            32           32
# Cardinal Binding Machine, Recycled                         88           88
# Cardinal Hole Reinforcements, Durable                      41           41
# Cardinal Hole Reinforcements, Economy                     349          349
# Ibico 3-Hole Punch, Clear                                 178          178
# Ibico Binder Covers, Clear                                385          385
# Ibico Binder Covers, Recycled                               1            1
# Ibico Binding Machine, Recycled                           199          199
# Ibico Hole Reinforcements, Clear                          558          558
# Ibico Hole Reinforcements, Economy                         76           76
# Ibico Index Tab, Clear                                     51           51
# Ibico Index Tab, Durable                                   22           22
# Pressboard Data Binder, Crimson, 12" X 8 1/2"               9            9
# Wilson Jones 3-Hole Punch, Clear                           22           22
# Wilson Jones 3-Hole Punch, Economy                          1            1
# Wilson Jones Binding Machine, Recycled                     20           20
# Wilson Jones Hanging Recycled Pressboard Data B...        159          159
# Wilson Jones Hole Reinforcements, Clear                    69           69
# Wilson Jones Hole Reinforcements, Economy                  84           84
# Wilson Jones Index Tab, Durable                             1            1
#
#                                                     Customer Name  Segment  \
# ProductName
# Acco 3-Hole Punch, Recycled                                     2        2
# Acco Binder Covers, Durable                                   135      135
# Acco Binding Machine, Economy                                  21       21
# Acco Binding Machine, Recycled                                123      123
# Acco Hole Reinforcements, Recycled                            362      362
# Acco Index Tab, Clear                                          33       33
# Ames Mailers, Recycled                                         12       12
# Avery 3-Hole Punch, Recycled                                   55       55
# Avery Binder Covers, Economy                                    1        1
# Avery Binder, Recycled                                         52       52
# Avery Binding Machine, Recycled                                12       12
# Avery Durable Binders                                         227      227
# Avery Hole Reinforcements, Durable                            159      159
# Avery Hole Reinforcements, Recycled                            58       58
# Cardinal 3-Hole Punch, Economy                                 47       47
# Cardinal 3-Hole Punch, Recycled                               126      126
# Cardinal Binder Covers, Clear                                   2        2
# Cardinal Binder Covers, Economy                               422      422
# Cardinal Binder, Clear                                         28       28
# Cardinal Binding Machine, Clear                                32       32
# Cardinal Binding Machine, Recycled                             88       88
# Cardinal Hole Reinforcements, Durable                          41       41
# Cardinal Hole Reinforcements, Economy                         349      349
# Ibico 3-Hole Punch, Clear                                     178      178
# Ibico Binder Covers, Clear                                    385      385
# Ibico Binder Covers, Recycled                                   1        1
# Ibico Binding Machine, Recycled                               199      199
# Ibico Hole Reinforcements, Clear                              558      558
# Ibico Hole Reinforcements, Economy                             76       76
# Ibico Index Tab, Clear                                         51       51
# Ibico Index Tab, Durable                                       22       22
# Pressboard Data Binder, Crimson, 12" X 8 1/2"                   9        9
# Wilson Jones 3-Hole Punch, Clear                               22       22
# Wilson Jones 3-Hole Punch, Economy                              1        1
# Wilson Jones Binding Machine, Recycled                         20       20
# Wilson Jones Hanging Recycled Pressboard Data B...            159      159
# Wilson Jones Hole Reinforcements, Clear                        69       69
# Wilson Jones Hole Reinforcements, Economy                      84       84
# Wilson Jones Index Tab, Durable                                 1        1
#
#                                                     City  State  ...  \
# ProductName                                                      ...
# Acco 3-Hole Punch, Recycled                            2      2  ...
# Acco Binder Covers, Durable                          135    135  ...
# Acco Binding Machine, Economy                         21     21  ...
# Acco Binding Machine, Recycled                       123    123  ...
# Acco Hole Reinforcements, Recycled                   362    362  ...
# Acco Index Tab, Clear                                 33     33  ...
# Ames Mailers, Recycled                                12     12  ...
# Avery 3-Hole Punch, Recycled                          55     55  ...
# Avery Binder Covers, Economy                           1      1  ...
# Avery Binder, Recycled                                52     52  ...
# Avery Binding Machine, Recycled                       12     12  ...
# Avery Durable Binders                                227    227  ...
# Avery Hole Reinforcements, Durable                   159    159  ...
# Avery Hole Reinforcements, Recycled                   58     58  ...
# Cardinal 3-Hole Punch, Economy                        47     47  ...
# Cardinal 3-Hole Punch, Recycled                      126    126  ...
# Cardinal Binder Covers, Clear                          2      2  ...
# Cardinal Binder Covers, Economy                      422    422  ...
# Cardinal Binder, Clear                                28     28  ...
# Cardinal Binding Machine, Clear                       32     32  ...
# Cardinal Binding Machine, Recycled                    88     88  ...
# Cardinal Hole Reinforcements, Durable                 41     41  ...
# Cardinal Hole Reinforcements, Economy                349    349  ...
# Ibico 3-Hole Punch, Clear                            178    178  ...
# Ibico Binder Covers, Clear                           385    385  ...
# Ibico Binder Covers, Recycled                          1      1  ...
# Ibico Binding Machine, Recycled                      199    199  ...
# Ibico Hole Reinforcements, Clear                     558    558  ...
# Ibico Hole Reinforcements, Economy                    76     76  ...
# Ibico Index Tab, Clear                                51     51  ...
# Ibico Index Tab, Durable                              22     22  ...
# Pressboard Data Binder, Crimson, 12" X 8 1/2"          9      9  ...
# Wilson Jones 3-Hole Punch, Clear                      22     22  ...
# Wilson Jones 3-Hole Punch, Economy                     1      1  ...
# Wilson Jones Binding Machine, Recycled                20     20  ...
# Wilson Jones Hanging Recycled Pressboard Data B...   159    159  ...
# Wilson Jones Hole Reinforcements, Clear               69     69  ...
# Wilson Jones Hole Reinforcements, Economy             84     84  ...
# Wilson Jones Index Tab, Durable                        1      1  ...
#
#                                                     Category  Sub-Category  \
# ProductName
# Acco 3-Hole Punch, Recycled                                2             2
# Acco Binder Covers, Durable                              135           135
# Acco Binding Machine, Economy                             21            21
# Acco Binding Machine, Recycled                           123           123
# Acco Hole Reinforcements, Recycled                       362           362
# Acco Index Tab, Clear                                     33            33
# Ames Mailers, Recycled                                    12            12
# Avery 3-Hole Punch, Recycled                              55            55
# Avery Binder Covers, Economy                               1             1
# Avery Binder, Recycled                                    52            52
# Avery Binding Machine, Recycled                           12            12
# Avery Durable Binders                                    227           227
# Avery Hole Reinforcements, Durable                       159           159
# Avery Hole Reinforcements, Recycled                       58            58
# Cardinal 3-Hole Punch, Economy                            47            47
# Cardinal 3-Hole Punch, Recycled                          126           126
# Cardinal Binder Covers, Clear                              2             2
# Cardinal Binder Covers, Economy                          422           422
# Cardinal Binder, Clear                                    28            28
# Cardinal Binding Machine, Clear                           32            32
# Cardinal Binding Machine, Recycled                        88            88
# Cardinal Hole Reinforcements, Durable                     41            41
# Cardinal Hole Reinforcements, Economy                    349           349
# Ibico 3-Hole Punch, Clear                                178           178
# Ibico Binder Covers, Clear                               385           385
# Ibico Binder Covers, Recycled                              1             1
# Ibico Binding Machine, Recycled                          199           199
# Ibico Hole Reinforcements, Clear                         558           558
# Ibico Hole Reinforcements, Economy                        76            76
# Ibico Index Tab, Clear                                    51            51
# Ibico Index Tab, Durable                                  22            22
# Pressboard Data Binder, Crimson, 12" X 8 1/2"              9             9
# Wilson Jones 3-Hole Punch, Clear                          22            22
# Wilson Jones 3-Hole Punch, Economy                         1             1
# Wilson Jones Binding Machine, Recycled                    20            20
# Wilson Jones Hanging Recycled Pressboard Data B...       159           159
# Wilson Jones Hole Reinforcements, Clear                   69            69
# Wilson Jones Hole Reinforcements, Economy                 84            84
# Wilson Jones Index Tab, Durable                            1             1
#
#                                                     Sales  Quantity  Discount  \
# ProductName
# Acco 3-Hole Punch, Recycled                             2         2         2
# Acco Binder Covers, Durable                           135       135       135
# Acco Binding Machine, Economy                          21        21        21
# Acco Binding Machine, Recycled                        123       123       123
# Acco Hole Reinforcements, Recycled                    362       362       362
# Acco Index Tab, Clear                                  33        33        33
# Ames Mailers, Recycled                                 12        12        12
# Avery 3-Hole Punch, Recycled                           55        55        55
# Avery Binder Covers, Economy                            1         1         1
# Avery Binder, Recycled                                 52        52        52
# Avery Binding Machine, Recycled                        12        12        12
# Avery Durable Binders                                 227       227       227
# Avery Hole Reinforcements, Durable                    159       159       159
# Avery Hole Reinforcements, Recycled                    58        58        58
# Cardinal 3-Hole Punch, Economy                         47        47        47
# Cardinal 3-Hole Punch, Recycled                       126       126       126
# Cardinal Binder Covers, Clear                           2         2         2
# Cardinal Binder Covers, Economy                       422       422       422
# Cardinal Binder, Clear                                 28        28        28
# Cardinal Binding Machine, Clear                        32        32        32
# Cardinal Binding Machine, Recycled                     88        88        88
# Cardinal Hole Reinforcements, Durable                  41        41        41
# Cardinal Hole Reinforcements, Economy                 349       349       349
# Ibico 3-Hole Punch, Clear                             178       178       178
# Ibico Binder Covers, Clear                            385       385       385
# Ibico Binder Covers, Recycled                           1         1         1
# Ibico Binding Machine, Recycled                       199       199       199
# Ibico Hole Reinforcements, Clear                      558       558       558
# Ibico Hole Reinforcements, Economy                     76        76        76
# Ibico Index Tab, Clear                                 51        51        51
# Ibico Index Tab, Durable                               22        22        22
# Pressboard Data Binder, Crimson, 12" X 8 1/2"           9         9         9
# Wilson Jones 3-Hole Punch, Clear                       22        22        22
# Wilson Jones 3-Hole Punch, Economy                      1         1         1
# Wilson Jones Binding Machine, Recycled                 20        20        20
# Wilson Jones Hanging Recycled Pressboard Data B...    159       159       159
# Wilson Jones Hole Reinforcements, Clear                69        69        69
# Wilson Jones Hole Reinforcements, Economy              84        84        84
# Wilson Jones Index Tab, Durable                         1         1         1
#
#                                                     Profit  Shipping Cost  \
# ProductName
# Acco 3-Hole Punch, Recycled                              2              2
# Acco Binder Covers, Durable                            135            135
# Acco Binding Machine, Economy                           21             21
# Acco Binding Machine, Recycled                         123            123
# Acco Hole Reinforcements, Recycled                     362            362
# Acco Index Tab, Clear                                   33             33
# Ames Mailers, Recycled                                  12             12
# Avery 3-Hole Punch, Recycled                            55             55
# Avery Binder Covers, Economy                             1              1
# Avery Binder, Recycled                                  52             52
# Avery Binding Machine, Recycled                         12             12
# Avery Durable Binders                                  227            227
# Avery Hole Reinforcements, Durable                     159            159
# Avery Hole Reinforcements, Recycled                     58             58
# Cardinal 3-Hole Punch, Economy                          47             47
# Cardinal 3-Hole Punch, Recycled                        126            126
# Cardinal Binder Covers, Clear                            2              2
# Cardinal Binder Covers, Economy                        422            422
# Cardinal Binder, Clear                                  28             28
# Cardinal Binding Machine, Clear                         32             32
# Cardinal Binding Machine, Recycled                      88             88
# Cardinal Hole Reinforcements, Durable                   41             41
# Cardinal Hole Reinforcements, Economy                  349            349
# Ibico 3-Hole Punch, Clear                              178            178
# Ibico Binder Covers, Clear                             385            385
# Ibico Binder Covers, Recycled                            1              1
# Ibico Binding Machine, Recycled                        199            199
# Ibico Hole Reinforcements, Clear                       558            558
# Ibico Hole Reinforcements, Economy                      76             76
# Ibico Index Tab, Clear                                  51             51
# Ibico Index Tab, Durable                                22             22
# Pressboard Data Binder, Crimson, 12" X 8 1/2"            9              9
# Wilson Jones 3-Hole Punch, Clear                        22             22
# Wilson Jones 3-Hole Punch, Economy                       1              1
# Wilson Jones Binding Machine, Recycled                  20             20
# Wilson Jones Hanging Recycled Pressboard Data B...     159            159
# Wilson Jones Hole Reinforcements, Clear                 69             69
# Wilson Jones Hole Reinforcements, Economy               84             84
# Wilson Jones Index Tab, Durable                          1              1
#
#                                                     Order Priority  Rating  \
# ProductName
# Acco 3-Hole Punch, Recycled                                      2       2
# Acco Binder Covers, Durable                                    135     135
# Acco Binding Machine, Economy                                   21      21
# Acco Binding Machine, Recycled                                 123     123
# Acco Hole Reinforcements, Recycled                             362     362
# Acco Index Tab, Clear                                           33      33
# Ames Mailers, Recycled                                          12      12
# Avery 3-Hole Punch, Recycled                                    55      55
# Avery Binder Covers, Economy                                     1       1
# Avery Binder, Recycled                                          52      52
# Avery Binding Machine, Recycled                                 12      12
# Avery Durable Binders                                          227     227
# Avery Hole Reinforcements, Durable                             159     159
# Avery Hole Reinforcements, Recycled                             58      58
# Cardinal 3-Hole Punch, Economy                                  47      47
# Cardinal 3-Hole Punch, Recycled                                126     126
# Cardinal Binder Covers, Clear                                    2       2
# Cardinal Binder Covers, Economy                                422     422
# Cardinal Binder, Clear                                          28      28
# Cardinal Binding Machine, Clear                                 32      32
# Cardinal Binding Machine, Recycled                              88      88
# Cardinal Hole Reinforcements, Durable                           41      41
# Cardinal Hole Reinforcements, Economy                          349     349
# Ibico 3-Hole Punch, Clear                                      178     178
# Ibico Binder Covers, Clear                                     385     385
# Ibico Binder Covers, Recycled                                    1       1
# Ibico Binding Machine, Recycled                                199     199
# Ibico Hole Reinforcements, Clear                               558     558
# Ibico Hole Reinforcements, Economy                              76      76
# Ibico Index Tab, Clear                                          51      51
# Ibico Index Tab, Durable                                        22      22
# Pressboard Data Binder, Crimson, 12" X 8 1/2"                    9       9
# Wilson Jones 3-Hole Punch, Clear                                22      22
# Wilson Jones 3-Hole Punch, Economy                               1       1
# Wilson Jones Binding Machine, Recycled                          20      20
# Wilson Jones Hanging Recycled Pressboard Data B...             159     159
# Wilson Jones Hole Reinforcements, Clear                         69      69
# Wilson Jones Hole Reinforcements, Economy                       84      84
# Wilson Jones Index Tab, Durable                                  1       1
#
#                                                     Group
# ProductName
# Acco 3-Hole Punch, Recycled                             2
# Acco Binder Covers, Durable                           135
# Acco Binding Machine, Economy                          21
# Acco Binding Machine, Recycled                        123
# Acco Hole Reinforcements, Recycled                    362
# Acco Index Tab, Clear                                  33
# Ames Mailers, Recycled                                 12
# Avery 3-Hole Punch, Recycled                           55
# Avery Binder Covers, Economy                            1
# Avery Binder, Recycled                                 52
# Avery Binding Machine, Recycled                        12
# Avery Durable Binders                                 227
# Avery Hole Reinforcements, Durable                    159
# Avery Hole Reinforcements, Recycled                    58
# Cardinal 3-Hole Punch, Economy                         47
# Cardinal 3-Hole Punch, Recycled                       126
# Cardinal Binder Covers, Clear                           2
# Cardinal Binder Covers, Economy                       422
# Cardinal Binder, Clear                                 28
# Cardinal Binding Machine, Clear                        32
# Cardinal Binding Machine, Recycled                     88
# Cardinal Hole Reinforcements, Durable                  41
# Cardinal Hole Reinforcements, Economy                 349
# Ibico 3-Hole Punch, Clear                             178
# Ibico Binder Covers, Clear                            385
# Ibico Binder Covers, Recycled                           1
# Ibico Binding Machine, Recycled                       199
# Ibico Hole Reinforcements, Clear                      558
# Ibico Hole Reinforcements, Economy                     76
# Ibico Index Tab, Clear                                 51
# Ibico Index Tab, Durable                               22
# Pressboard Data Binder, Crimson, 12" X 8 1/2"           9
# Wilson Jones 3-Hole Punch, Clear                       22
# Wilson Jones 3-Hole Punch, Economy                      1
# Wilson Jones Binding Machine, Recycled                 20
# Wilson Jones Hanging Recycled Pressboard Data B...    159
# Wilson Jones Hole Reinforcements, Clear                69
# Wilson Jones Hole Reinforcements, Economy              84
# Wilson Jones Index Tab, Durable                         1
#
# [39 rows x 25 columns]

# %%
output_df=df[['ProductName','Group']]

# %%
output_df=output_df.drop_duplicates().reset_index()

# %%
output_df=output_df[['ProductName','Group']].sort_values(by='Group')
output_df
# Out:
#                                            ProductName  \
# 128                   3M Hangers With Command Adhesive
# 42                                  Tenex Clock, Black
# 169                    9-3/4 Diameter Round Wall Clock
# 252  Howard Miller 13" Diameter Pewter Finish Round...
# 304                 Linden 10" Round Wall Clock, Black
# ..                                                 ...
# 195                                          Xerox 216
# 367                  SanDisk Parchment Paper, Recycled
# 58                      Xerox Parchment Paper, Premium
# 274             Southworth Parchment Paper & Envelopes
# 355             Array Parchment Paper, Assorted Colors
#
#                                 Group
# 128  3M Hangers With Command Adhesive
# 42    9-3/4 Diameter Round Wall Clock
# 169   9-3/4 Diameter Round Wall Clock
# 252   9-3/4 Diameter Round Wall Clock
# 304   9-3/4 Diameter Round Wall Clock
# ..                                ...
# 195                         Xerox 205
# 367    Xerox Parchment Paper, Premium
# 58     Xerox Parchment Paper, Premium
# 274    Xerox Parchment Paper, Premium
# 355    Xerox Parchment Paper, Premium
#
# [413 rows x 2 columns]

# %%
output_df.to_csv('output_df.csv')
